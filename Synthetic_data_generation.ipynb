# %% [markdown]
# <a href="https://colab.research.google.com/github/alhamedy/ML-Coding/blob/main/Synthetic_data_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd
import numpy as np
import random

# %%
filename = '100-nodes.csv'

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#    Node-ID  CPU-Utilization  Memory-Usage
# 0       N1          31.1600      0.073234
# 1       N2          30.5600     19.460000
# 2       N3          73.5340     91.679000
# 3       N4          67.0640     81.436000
# 4       N5          57.2050     57.659000
# ..     ...              ...           ...
# 95    N106           1.5179      0.913100
# 96    N108           1.2484      0.574310
# 97    N109           1.0843      0.213810
# 98    N110           1.2519      0.479380
# 99    N111           1.2824      0.597440
#
# [100 rows x 3 columns]

# %%
for i in range(1900):
    df = df.append({
        'CPU-Utilization': random.uniform(0, 100),
        'Memory-Usage': random.uniform(0, 100),
    }, ignore_index=True)
# Out:
# C:\Users\Ming\AppData\Local\Temp/ipykernel_24088/599309199.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\Ming\AppData\Local\Temp/ipykernel_24088/599309199.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\Ming\AppData\Local\Temp/ipykernel_24088/599309199.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\Ming\AppData\Local\Temp/ipykernel_24088/599309199.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# ...

# %%
df.to_csv('2000-nodes.csv', index=False)
